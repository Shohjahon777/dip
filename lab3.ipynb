# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('sealion_hero.png')
print(image.shape)

translation_matrix = np.float32([[1, 0, 100], [0, 1, 50]])

translation_image = cv2.warpAffine(image, translation_matrix, (image.shape[1], image.shape[0]))

print(translation_image.shape)
# Out:
# (1398, 1920, 3)
# (1398, 1920, 3)

# %%
plt.imshow(cv2.cvtColor(translation_image, cv2.COLOR_BGR2RGB))
plt.title('Translated Image')
plt.axis('off'),
plt.show()

# %%
(h, w) = image.shape[:2]
center = (w // 2 , h // 2)

rotation_matrix = cv2.getRotationMatrix2D(center, 180, 1.0)

rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
plt.title('Rotated image (45 degrees)')
plt.axis('off')
plt.show()

# %%
Factor = 2
scaling_matrix = cv2.getRotationMatrix2D((0,0), 0, Factor)

scaled_image = cv2.warpAffine(image, scaling_matrix, (w*Factor, h*Factor))

plt.imshow(cv2.cvtColor(scaled_image, cv2.COLOR_BGR2RGB))
plt.title("Scaled image 2x")
plt.axis('off')
plt.show()
print(scaled_image.shape)
# Out:
# (2796, 3840, 3)

# %%
m = 0.67

shearing_matrix = np.float32([[1, m, 0], [0, 1, 0]])
sheared_image = cv2.warpAffine(image, shearing_matrix, (w, h))


plt.imshow(cv2.cvtColor(sheared_image, cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (x-axis, factor ' + str(m) +')')
plt.axis('off')
plt.show()
plt.show()
